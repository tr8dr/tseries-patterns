# %%
import pandas as pd
import numpy as np

from tseries_patterns import AmplitudeBasedLabeler

# %% [markdown]
# # Data

# %%
df = pd.read_csv ("csv/XAUUSD.csv", parse_dates=["stamp"])

# %%
df.head()
# Out:
#                 stamp       open       high        low      close
# 0 2019-12-12 12:00:30  1474.7565  1474.9350  1474.7565  1474.8600
# 1 2019-12-12 12:01:00  1474.8600  1474.8650  1474.7800  1474.7815
# 2 2019-12-12 12:01:30  1474.7815  1474.7865  1474.7115  1474.7250
# 3 2019-12-12 12:02:00  1474.7250  1474.7350  1474.6700  1474.6700
# 4 2019-12-12 12:02:30  1474.6700  1474.6765  1474.6700  1474.6765

# %% [markdown]
# # Labeling (minamp = 10bps, Tinactive = 5mins)

# %% [markdown]
# The data is 30sec bars, so Tinactive is set to 10 samples to indicate max inactive time of 5 minutes

# %%
labeler = AmplitudeBasedLabeler (minamp = 10, Tinactive = 10)
labels = labeler.label (df)
labeler.plot()
# Out:
# <ggplot: (8785322898189)>

# %% [markdown]
# # Labeling (minamp = 20bps, Tinactive = 5mins)

# %%
labeler = AmplitudeBasedLabeler (minamp = 20, Tinactive = 10)
labels = labeler.label (df)
labeler.plot()
# Out:
# <ggplot: (8785307306201)>

# %% [markdown]
# # Allowing move to ride more noise

# %% [markdown]
# ## Labeling (minamp = 20bps, Tinactive = 15mins)

# %% [markdown]
# Increasing Tinactive to 15mins and minamplitude to 20bps allows for a move to ride through a significant amount of noise

# %%
labeler = AmplitudeBasedLabeler (minamp = 20, Tinactive = 30)
labels = labeler.label (df)
labeler.plot()
# Out:
# <ggplot: (8785339612733)>

# %% [markdown]
# ## Labeling (minamp = 10bps, Tinactive = 15mins)

# %%
labeler = AmplitudeBasedLabeler (minamp = 10, Tinactive = 30)
labels = labeler.label (df)
labeler.plot()
# Out:
# <ggplot: (8785254970981)>
